# %% [markdown]
# # 0800 time 1

# %% [markdown]
# Autoreload modules locally

# %%
# %reload_ext autoreload
# %autoreload  2

# %%
# %pylab inline
from quickplot import *
from IPython.parallel import Client
import cPickle as pickle
#rc = Client(sshserver='giulio@172.20.3.119',password='asdrubale')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['norm', 'power', 'rc', 'random', 'fft', 'linalg', 'info']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
rc = Client()
dview = rc[:]
# %px %load_ext autoreload
# %px %autoreload 2 
with dview.sync_imports():
    import time as tm
    import numpy as np
    import matplotlib.pyplot as plt 
    import pandas as pd
    from scipy.ndimage import measurements as meas
    from scipy.ndimage import center_of_mass
    from scipy.ndimage import median_filter
    from scipy.signal import medfilt
    import os
    from scipy.optimize import curve_fit
    from matplotlib.patches import Ellipse
    import Image
    # %px %load_ext autoreload
    # %px %autoreload 2 
    from Functions import SPring8_image, gauss_function, get_roi, parse_sample_parallel
    from Functions import showrois, norm, define_roi,save_suhtters, plot_dataframe, plot_shutters, smooth
    from Functions import spline_do, pandify, Version , save_spline_par, load_spline_par, load_data_frame
# Out:
# [stdout:0]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [stdout:1]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [stdout:2]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [stdout:3]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# importing time on engine(s)
# importing numpy on engine(s)
# importing matplotlib.pyplot on engine(s)
# importing pandas on engine(s)
# importing measurements from scipy.ndimage on engine(s)
# importing center_of_mass from scipy.ndimage on engine(s)
# importing median_filter from scipy.ndimage on engine(s)
# importing medfilt from scipy.signal on engine(s)
# importing os on engine(s)
# importing curve_fit from scipy.optimize on engine(s)
# importing Ellipse from matplotlib.patches on engine(s)
# importing Image on engine(s)
# importing Again from zmq.error on engine(s)
# importing strerror,zmq_errno from zmq.backend on engine(s)
# [stdout:0]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [stdout:1]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [stdout:2]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [stdout:3]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# importing SPring8_image,gauss_function,get_roi,parse_sample_parallel from Functions on engine(s)
# importing showrois,norm,define_roi,save_suhtters,plot_dataframe,plot_shutters,smooth from Functions on engine(s)
# importing spline_do,pandify,Version,save_spline_par,load_spline_par,load_data_frame from Functions on engine(s)

# %%
matplotlib.rcParams.update({'font.size': 14})
matplotlib.rcParams.update({'font.size': 14})
matplotlib.rcParams.update({'figure.figsize': (10.0, 8.0)})

# %% [markdown]
# ## Create directorty map

# %%
directory = 'InAs0800'

# %%
# !ls -d ./pilatus/$directory/*/
# Out:
# ./pilatus/InAs0800/1a/		   ./pilatus/InAs0800/time1/
# ./pilatus/InAs0800/InAs0800time3/  ./pilatus/InAs0800/time2a/
# ./pilatus/InAs0800/RSM/

# %%
name = 'time1'
files = !ls ./pilatus/$directory/$name/*.tif

# %%
len(files)
# Out:
# 3687

# %% [markdown]
# ## Push to Engines

# %%
puhsed_files = dview.push(dict(files=files))

pushed_functions = dview.push(dict(SPring8_image = SPring8_image,
                                    gauss_function = gauss_function,
                                    parse_sample_parallel = parse_sample_parallel,
                                    Version = Version ))

# %% [markdown]
# ## Define ROIs

# %%
roi = define_roi(files,name)
# Out:
# - ROI dump found, using it !
# - using loaded ROIs
# - ROI-dump-file found
# ---------------------
# done

# %% [markdown]
# ## Push roi to engines

# %%
dview.block = False
dview.push(dict(roi=roi))
ar = dview.pull('roi', block=False)
ar.get()
# Out:
# [{'TW': [340.0, 370.0, 80.0, 120.0],
#   'WZ': [200.0, 300.0, 80.0, 120.0],
#   'ZB': [100.0, 140.0, 80.0, 120.0]},
#  {'TW': [340.0, 370.0, 80.0, 120.0],
#   'WZ': [200.0, 300.0, 80.0, 120.0],
#   'ZB': [100.0, 140.0, 80.0, 120.0]},
#  {'TW': [340.0, 370.0, 80.0, 120.0],
#   'WZ': [200.0, 300.0, 80.0, 120.0],
#   'ZB': [100.0, 140.0, 80.0, 120.0]},
#  {'TW': [340.0, 370.0, 80.0, 120.0],
#   'WZ': [200.0, 300.0, 80.0, 120.0],
#   'ZB': [100.0, 140.0, 80.0, 120.0]}]

# %% [markdown]
# Check version of the loaded modules.

# %%
print Version()
# Out:
# last update Date: 2013-12-16

# %%
dview.map_sync(lambda x: Version(),[1])
# Out:
# ['last update Date: 2013-12-16']

# %% [markdown]
# # Start parallel analysis

# %%
raw_input()
# Out:
# no!
# 'no!'

# %%
start_time = tm.time()
samples = {}
#
# %px i = 0 # first roi
i = 0
std = 10
print roi.keys()[i]
samples[roi.keys()[i]] = list( flatten( dview.map_sync(lambda x: parse_sample_parallel(x,roi[roi.keys()[i]],2),files)))
elapsed_time = tm.time() - start_time
print elapsed_time
#
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-5013f2dc46e9> in <module>()
#       6 std = 10
#       7 print roi.keys()[i]
# ----> 8 samples[roi.keys()[i]] = list( flatten( dview.map_sync(lambda x: parse_sample_parallel(x,roi[roi.keys()[i]],2),files)))
#       9 elapsed_time = tm.time() - start_time
#      10 print elapsed_time
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/cbook.pyc in flatten(seq, scalarp)
#     804     and Recipe 1.12 in cookbook
#     805     """
# --> 806     for item in seq:
#     807         if scalarp(item):
#     808             yield item
#
# /home/giulio/opt/ipython/IPython/parallel/client/asyncresult.pyc in __iter__(self)
#     592     def __iter__(self):
#     593         it = self._ordered_iter if self.ordered else self._unordered_iter
# --> 594         for r in it():
#     595             yield r
#     596
#
# /home/giulio/opt/ipython/IPython/parallel/client/asyncresult.pyc in _ordered_iter(self)
#     604             for msg_id in self.msg_ids:
#     605                 ar = AsyncResult(self._client, msg_id, self._fname)
# --> 606                 rlist = ar.get()
#     607                 try:
#     608                     for r in rlist:
#
# /home/giulio/opt/ipython/IPython/parallel/client/asyncresult.pyc in get(self, timeout)
#     110         """
#     111         if not self.ready():
# --> 112             self.wait(timeout)
#     113
#     114         if self._ready:
#
# /home/giulio/opt/ipython/IPython/parallel/client/asyncresult.pyc in wait(self, timeout)
#     141             self._wait_for_outputs(timeout)
#     142             return
# --> 143         self._ready = self._client.wait(self.msg_ids, timeout)
#     144         if self._ready:
#     145             try:
#
# /home/giulio/opt/ipython/IPython/parallel/client/client.pyc in wait(self, jobs, timeout)
#    1080             if timeout >= 0 and ( time.time()-tic ) > timeout:
#    1081                 break
# -> 1082             time.sleep(1e-3)
#    1083             self.spin()
#    1084         return len(theids.intersection(self.outstanding)) == 0
#
# KeyboardInterrupt:
# TW

# %%
#
split_time = tm.time()
# %px i = 1 # second roi
i = 1
# %px std = 4
print roi.keys()[i]
samples[roi.keys()[i]] = list( flatten( dview.map_sync(lambda x: parse_sample_parallel(x,roi[roi.keys()[i]],2,std),files)))
elapsed_time = tm.time() - split_time
print elapsed_time
#
# Out:
# WZ
# 332.589725018

# %%
split_time = tm.time()
# %px i = 2 # third roi
i =2 
# %px std = 10
print roi.keys()[i]
samples[roi.keys()[i]] = list( flatten( dview.map_sync(lambda x: parse_sample_parallel(x,roi[roi.keys()[i]],2,std),files)))

elapsed_time = tm.time() - split_time
print elapsed_time
total_elapsed_time = tm.time() - start_time
print 'Total time used %s miuntes'%(total_elapsed_time/60.)
# Out:
# ZB
# 261.762701988
# Total time used 14.4744247635 miuntes

# %% [markdown]
# ## Pand-ify data

# %%
data = load_data_frame(name)
if not data:
    data = pandify(samples,roi,name)
# Out:
# data frame loaded

# %%
on_off = save_suhtters(name)
# Out:
# on_off dump found, using it !

# %% [markdown]
# Define an off_set for the shutter opening/closing effect. very empirical !

# %%
offset_list =  [[5,5] for i in range(len(on_off))] #[[5,56],[10,56]]

# %%
fig,ax = plot_dataframe(data,False,False)

# %%
plot_shutters(on_off,data,ax,offset=offset_list,ls='--', color='k')
# Out:
# ok

# %%
try: 
    showrois(samples,roi,100)
except NameError:
    print 'running in local mode, samples not defined'
# Out:
# running in local mode, samples not defined

# %% [markdown]
# Test  one sample

# %%
parameters_dict = load_spline_par(name)
# Out:
# spline_parameters dump found, using it !

# %%
parameters_dict = {'TW': 800000, 'WZ':1085, 'ZB': 885}
save_spline_par(parameters_dict, name)
# Out:
# searching parameters_dict object
# parameters_dict object found, dumping it to disk

# %%
fig = do(data, 'WZ', parameters_dict,name)
# Out:
# on_off dump found, using it !
# ok

# %%
fig = do(data, 'ZB', parameters_dict ,name)
# Out:
# on_off dump found, using it !
# ok

# %%
fig = do(data, 'TW', parameters_dict ,name)
# Out:
# on_off dump found, using it !
# ok

# %%
fig,ax = do_diff_derivatives(data,parameters_dict,'ZB',name,True,True);
ax.set_xlim(100,500)
ax.set_xlabel('Time(s)')
# Out:
# on_off dump found, using it !
# ok

# %%
ax.set_xlim(500,4000)
fig

# %%
fig, ax = do_diff_derivatives(data,parameters_dict,'TW',name,True,False)
ax.set_xlim(100,500)
ax.set_xlabel('Time(s)')
# Out:
# on_off dump found, using it !
# ok

# %%
ax.set_xlim(500,4000)
fig

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
#     @font-face {
#                 font-family: 'HelveticaNeue-UltraLight', 'Helvetica Neue UltraLight', 'Helvetica Neue', Arial, Helvetica, sans-serif; font-weight: 100; letter-spacing: 1px;
#     }
#     div.cell{
#         width: 90%;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     ul {
#         line-height: 145%;
#         font-size: 90%;
#     }
#     li {
#         margin-bottom: 1em;
#     }
#     h1 {
#         font-family: 'HelveticaNeue-UltraLight', 'Helvetica Neue UltraLight', 'Helvetica Neue', Arial, Helvetica, sans-serif; font-weight: 500; letter-spacing: 1px;
#     }
#     h4{
#         margin-top: 12px;
#         margin-bottom: 3px;
#        }
#     div.text_cell_render{
#         font-family: 'HelveticaNeue-Light', 'Helvetica Neue Light', 'Helvetica Neue', Arial, Helvetica, sans-serif; font-weight: 100; letter-spacing: 1px;
#         line-height: 105%;
#         font-size: 11pt;
#         width: 90%;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
# family    }
# /*    .prompt{
#         display: None;
#     }*/
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 16pt;
#         color: #4057A1;
#         font-style: italic;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     div.text_cell_render h1 {
#         font-family: 'HelveticaNeue-UltraLight', 'Helvetica Neue UltraLight', 'Helvetica Neue', Arial, Helvetica, sans-serif; font-weight: 500; letter-spacing: 1px;
#         line-height: 145%;
#         font-size: 30pt;
#         color: #333333;
#         width: 90%;
#         margin-left:auto;
#         margin-right:auto;
#     }
#
#     div.text_cell_render h2{
#         font-family: 'HelveticaNeue-UltraLight', 'Helvetica Neue UltraLight', 'Helvetica Neue', Arial, Helvetica, sans-serif; font-weight: 500; letter-spacing: 1px;
#         color:#FF5200;
#
#     }
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
#
#     div.output {
#         /*max-width:900px;*/
#         /*width: 99%;*/
#         text-align: center;
#         width: 90%;
#         margin-left:auto;
#         margin-right:auto;
#
#     }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %%
on_off
# Out:
# [62.5269, 166.59, 1766.54, 3163.0515]
