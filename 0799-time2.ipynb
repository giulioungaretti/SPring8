# %% [markdown]
# # 0799-time2

# %%
import matplotlib
matplotlib.rcParams.update({'font.size': 14})
matplotlib.rcParams.update({'figure.figsize': (10.0, 8.0)})
# %reload_ext autoreload
# %autoreload  2

# %%
# %pylab inline
from quickplot import *
from IPython.parallel import Client
import cPickle as pickle
#rc = Client(sshserver='giulio@172.20.3.119',password='asdrubale')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
rc = Client()
dview = rc[:]
# %px %load_ext autoreload
# %px %autoreload 2 
with dview.sync_imports():
    import time as tm
    import numpy as np
    import matplotlib.pyplot as plt 
    import pandas as pd
    from scipy.ndimage import measurements as meas
    from scipy.ndimage import center_of_mass
    from scipy.ndimage import median_filter
    from scipy.signal import medfilt
    import os
    from scipy.optimize import curve_fit
    from matplotlib.patches import Ellipse
    import Image
    # %px %load_ext autoreload
    # %px %autoreload 2 
    from Functions import SPring8_image, gauss_function, get_roi, parse_sample_parallel
    from Functions import showrois, norm, define_roi,save_suhtters, plot_dataframe, plot_shutters, smooth
    from Functions import spline_do, pandify, Version , save_spline_par, load_spline_par, load_data_frame
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-5-e971caf3d33c> in <module>()
# ----> 1 rc = Client()
#       2 dview = rc[:]
#       3 get_ipython().magic(u'px %load_ext autoreload')
#       4 get_ipython().magic(u'px %autoreload 2')
#       5 with dview.sync_imports():
#
# /home/giulio/opt/ipython/IPython/parallel/client/client.pyc in __init__(self, url_file, profile, profile_dir, ipython_dir, context, debug, sshserver, sshkey, password, paramiko, timeout, cluster_id, **extra_args)
#     409             )
#     410
# --> 411         with open(url_file) as f:
#     412             cfg = json.load(f)
#     413
#
# IOError: [Errno 2] No such file or directory: u'/home/giulio/.ipython/profile_default/security/ipcontroller-client.json'

# %% [markdown]
# ## Create directorty map

# %%
# !ls -d ./pilatus/InAs0799/*/
# Out:
# ./pilatus/InAs0799/InAs0799time1/   ./pilatus/InAs0799/InAs0799time3/
# ./pilatus/InAs0799/InAs0799time1a/  ./pilatus/InAs0799/InAs0799time4/
# ./pilatus/InAs0799/InAs0799time2/   ./pilatus/InAs0799/RSM/

# %%
name = 'InAs0799time2'
files = !ls ./pilatus/InAs0799/$name/*.tif
puhsed_files = dview.push(dict(files=files))
pushed_functions = dview.push(dict(SPring8_image=SPring8_image,
                                   gauss_function=gauss_function,
                                   parse_sample_parallel=parse_sample_parallel))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-90c28fb47f3d> in <module>()
#       1 name = 'InAs0799time2'
#       2 files = get_ipython().getoutput(u'ls ./pilatus/InAs0799/$name/*.tif')
# ----> 3 puhsed_files = dview.push(dict(files=files))
#       4 pushed_functions = dview.push(dict(SPring8_image=SPring8_image,
#       5                                    gauss_function=gauss_function,
#
# NameError: name 'dview' is not defined

# %%
len(files)
# Out:
# 400

# %% [markdown]
# ## Define ROIs

# %%
roi = define_roi(files,name)
# Out:
# - no ROI found, define them
# - create new ROI
# - create ZB
# x_1:100
# x_2:150
# y_1:70
# y_2:125
# return if ok,space to redo
# x_1:100
# x_2:140
# y_1:70
# y_2:125
# return if ok,space to redo
# - create TW
# x_1:300
# x_2:370
# y_1:80
# y_2:120
# return if ok,space to redo
# x_1:340
# x_2:370
# y_1:80
# y_2:110
# return if ok,space to redo
# - create wZ
# x_1:200
# x_2:300
# y_1:80
# y_2:120
# return if ok,space to redo
# x_1:225
# x_2:250
# y_1:90
# y_2:110
# return if ok,space to redo
# - ROI-dump-file not found, creating it..
# ROI found, dump it to disk

# %% [markdown]
# ## Push roi to engines

# %%
dview.block = False
dview.push(dict(roi=roi))
ar = dview.pull('roi', block=False)
ar.get()
# Out:
# [{'TW': [340.0, 370.0, 80.0, 110.0],
#   'WZ': [225.0, 250.0, 90.0, 110.0],
#   'ZB': [100.0, 140.0, 70.0, 125.0]},
#  {'TW': [340.0, 370.0, 80.0, 110.0],
#   'WZ': [225.0, 250.0, 90.0, 110.0],
#   'ZB': [100.0, 140.0, 70.0, 125.0]},
#  {'TW': [340.0, 370.0, 80.0, 110.0],
#   'WZ': [225.0, 250.0, 90.0, 110.0],
#   'ZB': [100.0, 140.0, 70.0, 125.0]},
#  {'TW': [340.0, 370.0, 80.0, 110.0],
#   'WZ': [225.0, 250.0, 90.0, 110.0],
#   'ZB': [100.0, 140.0, 70.0, 125.0]}]

# %% [markdown]
# Check version of the loaded modules

# %%
print Version()
# Out:
# last update-2013-12-11 6:19

# %%
dview.map_sync(lambda x: Version(),[1])
# Out:
# ['last update-2013-12-11 6:19 ']

# %% [markdown]
# # Start parallel analysis

# %%
start_time = tm.time()
samples = {}
#
# %px i = 0 # first roi
i = 0
std = 4
print roi.keys()[i]
samples[roi.keys()[i]] = list( flatten( dview.map_sync(lambda x: parse_sample_parallel(x,roi[roi.keys()[i]],2),files)))
elapsed_time = tm.time() - start_time
print elapsed_time
#
# Out:
# TW
# 22.8210039139

# %%
#
split_time = tm.time()
# %px i = 1 # second roi
i = 1
# %px std = 4
print roi.keys()[i]
samples[roi.keys()[i]] = list( flatten( dview.map_sync(lambda x: parse_sample_parallel(x,roi[roi.keys()[i]],2,std),files)))
elapsed_time = tm.time() - split_time
print elapsed_time
#
# Out:
# WZ
# 22.4316959381

# %%
split_time = tm.time()
# %px i = 2 # third roi
i =2 
# %px std = 15
print roi.keys()[i]
samples[roi.keys()[i]] = list( flatten( dview.map_sync(lambda x: parse_sample_parallel(x,roi[roi.keys()[i]],2,std),files)))

elapsed_time = tm.time() - split_time
print elapsed_time
total_elapsed_time = tm.time() - start_time
print 'Total time used %s miuntes'%(total_elapsed_time/60.)
# Out:
# ZB
# 22.6464750767
# Total time used 1.13297393322 miuntes

# %% [markdown]
# ## Pand-ify data

# %%
data = load_data_frame(name)
if not data:
    data = pandify(samples,roi,name)
# Out:
# data frame loaded

# %%
# !ls *.p
# Out:
# InAs0798ROI.p			   InAs0801time2aspline_parameters.p
# InAs0798shutter.p		   InAs0801time2bROI.p
# InAs0798spline_parameters.p	   InAs0801time2bshutter.p
# InAs0799time1aROI.p		   InAs0801time2bspline_parameters.p
# InAs0799time1ashutter.p		   InAs0801time3aROI.p
# InAs0799time1aspline_parameters.p  InAs0801time3ashutter.p
# InAs0799time2ROI.p		   InAs0801time3aspline_parameters.p
# InAs0799time2shutter.p		   shutter.p
# InAs0799time2spline_parameters.p   time1ROI.p
# InAs0799time3ROI.p		   time1shutter.p
# InAs0799time3shutter.p		   time1spline_parameters.p
# InAs0799time3spline_parameters.p   time2aROI.p
# InAs0801time2ashutter.p		   time2aspline_parameters.p

# %%
on_off = save_suhtters(name)
# Out:
# no on_off found, define them
# Suhtter on  time:65
# Suhtter on  time:501
# more (leave empty to continue)?
# on_off-dump-file not found, creating it..
# on_off object found, dumping it to disk

# %% [markdown]
# Define an off_set for the shutter opening/closing effect. very empirical !

# %%
offset_list =  [[5,56],[10,56]]

# %%
fig,ax = plot_dataframe(data,False,False)

# %%
plot_shutters(on_off,data,ax,offset=offset_list,ls='--', color='k')
# Out:
# ok

# %% [markdown]
# WZ plot

# %%
parameters_dict = {'TW': 10000, 'WZ':70, 'ZB': 10000}
save_spline_par(parameters_dict, name)
# Out:
# searching parameters_dict object
# parameters_dict object found, dumping it to disk

# %%
fig = do(data, 'WZ', parameters_dict,name)
# Out:
# on_off dump found, using it !
# ok

# %%
fig = do(data, 'TW', parameters_dict,name)
# Out:
# on_off dump found, using it !
# ok

# %%
fig = do(data, 'ZB', parameters_dict,name)
# Out:
# on_off dump found, using it !
# ok

# %%
do_diff_derivatives(data,parameters_dict,'ZB',name,True,False);
# Out:
# on_off dump found, using it !
# ok

# %%
fig,ax = do_diff_derivatives(data,parameters_dict,'TW',name,True,True)
ax.set_xlabel('Time(s)')
fig
# Out:
# on_off dump found, using it !
# ok

# %%
def css_styling():
    styles = open("styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-6f3ad1d772dd> in <module>()
#       2     styles = open("styles/custom.css", "r").read()
#       3     return HTML(styles)
# ----> 4 css_styling()
#
# <ipython-input-93-6f3ad1d772dd> in css_styling()
#       1 def css_styling():
#       2     styles = open("styles/custom.css", "r").read()
# ----> 3     return HTML(styles)
#       4 css_styling()
#
# NameError: global name 'HTML' is not defined
