# %%
# %load_ext autoreload
# %autoreload 2
from quickplot import *
from quickplot import shade
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-00393e5d737a> in <module>()
#       2 get_ipython().magic(u'load_ext autoreload')
#       3 get_ipython().magic(u'autoreload 2')
# ----> 4 from quickplot import *
#       5 from quickplot import shade
#
# /Volumes/DATA/SPring8-data/quickplot.py in <module>()
# ----> 1 from pylab import *
#       2 from Functions import *
#       3 import pandas as pd
#       4
#       5 name = ''
#
# /Users/Giulio/anaconda/lib/python2.7/site-packages/pylab.py in <module>()
# ----> 1 from matplotlib.pylab import *
#       2 import matplotlib.pylab
#       3 __doc__ = matplotlib.pylab.__doc__
#
# /Users/Giulio/anaconda/lib/python2.7/site-packages/matplotlib/pylab.py in <module>()
#     267 from numpy.linalg import *
#     268
# --> 269 from matplotlib.pyplot import *
#     270
#     271 # provide the recommended module abbrevs in the pylab namespace
#
# /Users/Giulio/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py in <module>()
#      96
#      97 from matplotlib.backends import pylab_setup
# ---> 98 _backend_mod, new_figure_manager, draw_if_interactive, _show = pylab_setup()
#      99
#     100
#
# /Users/Giulio/anaconda/lib/python2.7/site-packages/matplotlib/backends/__init__.pyc in pylab_setup()
#      26     # imports. 0 means only perform absolute imports.
#      27     backend_mod = __import__(backend_name,
# ---> 28                              globals(),locals(),[backend_name],0)
#      29
#      30     # Things we pull in from all backends
#
# /Users/Giulio/anaconda/lib/python2.7/site-packages/matplotlib/backends/backend_qt4agg.py in <module>()
#      11
#      12 from backend_agg import FigureCanvasAgg
# ---> 13 from backend_qt4 import QtCore, QtGui, FigureManagerQT, FigureCanvasQT,\
#      14      show, draw_if_interactive, backend_version, \
#      15      NavigationToolbar2QT
#
# /Users/Giulio/anaconda/lib/python2.7/site-packages/matplotlib/backends/backend_qt4.py in <module>()
#      23     figureoptions = None
#      24
# ---> 25 from qt4_compat import QtCore, QtGui, _getSaveFileName, __version__
#      26
#      27 backend_version = __version__
#
# /Users/Giulio/anaconda/lib/python2.7/site-packages/matplotlib/backends/qt4_compat.py in <module>()
#      34 # Now perform the imports.
#      35 if QT_API in (QT_API_PYQT, QT_API_PYQTv2):
# ---> 36     import sip
#      37     if QT_API == QT_API_PYQTv2:
#      38         if QT_API_ENV == 'pyqt':
#
# ImportError: No module named sip

# %%
def shade(on_off, ax):
    for on, off in zip(on_off[:-1:2], on_off[1::2]):
            on = on + data.index.values.min()
            off = off + data.index.values.min()
            ax.add_patch(Rectangle((on, -1), off - on, 2, facecolor="grey"))

# %%
name = 'InAs0799time3'
data, parameters_dict, on_off, offset_list = loadme(name)
fig_1, ax_1 = do_diff_derivatives(
    data, parameters_dict, 'TW', name, False, True, True, True,figsize=(8,5))

ax_1.plot(data.index,data.Int_WZ)
ax_1.set_xlim(300,800)
ax_1.set_xlabel('Time(s)')
# Out:
# data frame loaded
# parameters_dict loaded
# on_off dump found, using it !
# on off loaded
# offset_list done
# on_off dump found, using it !

# %%
x = data.index
y = data.Int_WZ
xs_WZ, ys_WZ, d_ys_WZ, dd_ys_WZ = spline_do(
    x, y, [ax_1], n=3, s=parameters_dict['WZ'], k=3, plot=False)

# %%
x = data.index
y_TW = data.Int_TW
xs_TW, ys_TW, d_ys_TW, dd_ys_TW = spline_do(
    x, y_TW, [ax], n=3, s=parameters_dict['TW'], k=3, plot=False)

# %% [markdown]
# WZ

# %%
fig,ax = subplots(figsize=(15,10))
ax.plot(xs_WZ,d_ys_WZ,label='spline')
for mean in [13,21]:
    for median in [10,41]:
        plot(data.index, pd.rolling_mean(pd.rolling_median(data.Int_WZ,median).diff(),mean),'-',label = '''moving avg window:{0},
        moving median window:{1}'''.format(mean,median) )
ax.legend()

# %%
ax.set_xlim(50,400)
ax.set_ylim(-.01,.04)
shade(on_off,ax)
fig

# %% [markdown]
# TW

# %%
fig,ax = subplots(figsize=(15,10))
ax.plot(xs_TW,d_ys_TW,label='spline')
for mean in [13,21]:
    for median in [10,41]:
        plot(data.index, pd.rolling_mean(pd.rolling_median(data.Int_TW,median).diff(),mean),'-',label = '''moving avg window:{0},
        moving median window:{1}'''.format(mean,median) )
ax.legend()

# %%
ax.set_xlim(50,400)
ax.set_ylim(-.01,1)
shade(on_off,ax)
fig

# %%
mean = 20
median = 10 
d_wz = pd.rolling_mean(pd.rolling_median(data.Int_WZ,median).diff(),mean)
d_tw =  pd.rolling_mean(pd.rolling_median(data.Int_TW,median).diff(),mean)

ax_1.plot(data.index, norm(d_wz)-norm(d_tw))
fig_1
