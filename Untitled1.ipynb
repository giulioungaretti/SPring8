# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
from quickplot import *
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# WARNING: pylab import has clobbered these variables: ['norm', 'power', 'mean', 'median', 'random', 'fft', 'linalg', 'info']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
x = data.index
y = data.Int_WZ
xs_WZ, ys_WZ, d_ys_WZ, dd_ys_WZ = spline_do(
    x, y, [ax], n=3, s=parameters_dict['WZ'], k=3, plot=False)

# %%
data.

# %%
fig,ax = subplots(figsize=(15,10))

ax.plot(d_ys_WZ,label='spline')
for mean in [5,21]:
    for median in [21]:
        plot(pd.rolling_mean(pd.rolling_median(data.Int_WZ,mean).diff(),median),'-',label = '''moving avg window:{0},
        moving median window:{1}'''.format(mean,median) )
ax.legend()

# %%
ax.set_xlim(0,300)
ax.set_ylim(-.01,.04)
fig

# %%
fig,ax = subplots(figsize=(15,10))
ax.plot(data.Int_WZ)
ax.set_xlim(0,300)
ax.set_ylim(12,16)
# Out:
# (12, 16)

# %%
name = 'InAs0799time3'
data, parameters_dict, on_off, offset_list = loadme(name)
fig, ax = do_diff_derivatives(
    data, parameters_dict, 'TW', name, False, True, True, True,figsize=(8,5))

ax.plot(data.index,data.Int_WZ)
ax.set_xlim(300,800)
ax.set_xlabel('Time(s)')
# Out:
# data frame loaded
# parameters_dict loaded
# on_off dump found, using it !
# on off loaded
# offset_list done
# on_off dump found, using it !

# %%
fig.savefig('peter_0799.png', dpi=400)
