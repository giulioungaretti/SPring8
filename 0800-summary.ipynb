# %%
# %pylab inline
from Functions import *
from matplotlib import rc
# %load_ext autoreload
# %autoreload 2

### matplotlib custom

rc('font',**{'size'   : 20})
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# WARNING: pylab import has clobbered these variables: ['norm', 'step', 'rc']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
names = ['time1','time2a','InAs0800time3a']
specnames= ['InAs0800time1','InAs0800time2a','InAs0800time3a']

# %%
fig,ax = subplots(figsize=(15,4))
time = []
int_wz= []
on_offs = [] 
###
data, parameters_dict, on_off, offset_list = loadme(names[0])
spec_df = load_spec_log(specnames[0],lines =1 )
data['Time'] = spec_df.Time.values
x1 = data.Time
y1=  data.Int_WZ
ax.plot(x1, y1,'grey' )
shade(on_off,ax,lim=300)
time.append(x1)
int_wz.append(y1)

#########

on_offs.append(on_off+x1[0])
# Out:
# data frame loaded
# parameters_dict loaded
# on_off dump found, using it !
# on off loaded
# offset_list done

# %%
data, parameters_dict, on_off, offset_list = loadme(names[1])
spec_df = load_spec_log(specnames[1],1)
data['Time'] = spec_df.Time.values
#data =  data[data.Int_WZ > 200 ]
x2=  data.Time + x1[-1]
y2 =  ( y1[-1] - data.Int_WZ[0]) + data.Int_WZ
ax.plot(x2,  y2,'grey' )
on_off = on_off + x2[0]
shade(on_off,ax,lim=300)
time.append(x2)
int_wz.append(y2)
on_offs.append(on_off)
fig
# Out:
# data frame loaded
# parameters_dict loaded
# on_off dump found, using it !
# on off loaded
# offset_list done

# %%
on_offs
# Out:
# [array([   62.52923606,   545.00323606,  1766.54323606,  3433.00323606]),
#  array([ 4109.48298715,  7849.48298715])]

# %%
data, parameters_dict, on_off, offset_list = loadme(names[2])
spec_df = load_spec_log(names[2])
data['Time'] = spec_df.Time.values


x3 = data.Time + x2[-1]

y3 = (y2[-1]- data.Int_WZ[0]) + data.Int_WZ

ax.plot(x3,  y3, 'gray' )

on_off = on_off + x3[0]
shade(on_off,ax,lim=300)
time.append(x3)
int_wz.append(y3)

on_offs.append(on_off)
fig
# Out:
# data frame loaded
# parameters_dict loaded
# on_off dump found, using it !
# on off loaded
# offset_list done

# %%
on_offs = list(flatten(on_offs))

# %%
time = numpy.concatenate([x1,x2,x3])
int_wz = numpy.concatenate([y1,y2,y3])

# %%
step = 50
delta_h =  int_wz[step::step]- int_wz[:-step:step]
h = np.cumsum(delta_h)

# %%
#fig, ax2 = subplots(figsize=(15,5))
ax2= ax.twinx()
lefts = time[::50][:-1]
    
ax2.bar(lefts,h ,  align='center', width=30,color='black')

ax2.bar(lefts,h, width=10,  align='center', color='grey')

ax2.set_frame_on(False)
ax2.get_xaxis().tick_bottom()
ax2.get_yaxis().tick_left()
[i.grid('off') for i in fig.get_axes()]
# ax2.axes.get_yaxis().set_visible(False)
#ax2.set_xlim(0,3500)
ax2.set_yticklabels([])

xmin, xmax = ax2.get_xaxis().get_view_interval()
ymin, ymax = ax2.get_yaxis().get_view_interval()
ax2.add_artist(Line2D((xmin, xmax), (ymin, ymin), color='black', linewidth=2))
ax2.set_xlabel('Time (s)')
ax2.set_ylabel(' NW lenght (a.u.)')

# %%
# [i.set_alpha(0) for i in ax.get_lines()]
# [i.grid('off') for i in fig.get_axes()]
# ax.set_frame_on(False)
# ax.get_xaxis().tick_bottom()

# ax.axes.get_yaxis().set_visible(False)

# ###  add x line

# %%
fig

# %%
# !git commit -m 'added 800 summary'
# Out:
# [cleanup ef8cc1f] added 800 summary
#  1 file changed, 418 insertions(+)
#  create mode 100644 0800-summary.ipynb
