# %% [markdown]
# Import

# %%
### magics
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %reload_ext autoreload
# %autoreload  2
from Functions import *
from pyqtgraph.Qt import QtGui, QtCore 
import pyqtgraph as pg
# Out:
# Can't use kdist without the 'coords' package
# reg_gal2cel requires coords & pyregion
# posang requires coords
# Region Photometry requires pyregion
# Cannot import montage.
# cubes.py requires coords for aper_world2pix and coords_in_image
# cubes.py requires pyregion for getspec_reg
# cubes.py requires pywcs for some subimage_integ,aper_wordl2pix,getspec, and coords_in_image

# %% [markdown]
# Matplotlib tweak

# %%
matplotlib.rcParams.update({'font.size': 20})
matplotlib.rcParams.update({'figure.figsize': (10.0, 8.0)})

# %% [markdown]
# Paralle set up

# %%
from IPython.parallel import Client
css_styling()
rc = Client()
dview = rc[:]
# %px clear
# Out:
# [stdout:0]
# [stdout:1]
# [stdout:2]
# [stdout:3]

# %% [markdown]
# Importing on engines

# %%
# %px %load_ext autoreload
# %px %autoreload 2

# %%
with dview.sync_imports():
    from collections import deque
    import time as tm
    import numpy as np
    import matplotlib.pyplot as plt 
    import pandas as pd
    from scipy.ndimage import measurements as meas
    from scipy.ndimage import center_of_mass
    from scipy.ndimage import median_filter
    from scipy.signal import medfilt
    import os
    from scipy.optimize import curve_fit
    from matplotlib.patches import Ellipse
    import Image
    from Functions import  SPring8_image, gauss_function, parse_headers, Version, pandify_header, fit_parallel
    import agpy as agf
# Out:
# importing deque from collections on engine(s)
# importing time on engine(s)
# importing numpy on engine(s)
# importing matplotlib.pyplot on engine(s)
# importing pandas on engine(s)
# importing measurements from scipy.ndimage on engine(s)
# importing center_of_mass from scipy.ndimage on engine(s)
# importing median_filter from scipy.ndimage on engine(s)
# importing medfilt from scipy.signal on engine(s)
# importing os on engine(s)
# importing curve_fit from scipy.optimize on engine(s)
# importing Ellipse from matplotlib.patches on engine(s)
# importing Image on engine(s)
# importing SPring8_image,gauss_function,parse_headers,Version,pandify_header,fit_parallel from Functions on engine(s)
# importing agpy on engine(s)

# %% [markdown]
# ## Create directory map

# %%
name = 'InAs0799time3'
files = !ls ./pilatus/InAs0799/$name/*.tif
puhsed_files = dview.push(dict(files=files))
pushed_functions = dview.push(dict(SPring8_image = SPring8_image,
                                    gauss_function=gauss_function,
                                    parse_headers = parse_headers,
                                    fit_parallel = fit_parallel))

# %% [markdown]
# load hkl

# %%
name_hkl = 'InAs0799'
H = loadtxt('./'+name_hkl+'/H.dat')
L = loadtxt('./'+name_hkl+'/L.dat')
K = loadtxt('./'+name_hkl+'/K.dat')

# %% [markdown]
# load times

# %%
spec_df = load_spec_log(name)
time = spec_df.Time.values

# %% [markdown]
# ## load headers

# %%
samples = deque(flatten( dview.map_sync(lambda x: parse_headers(x,2),files)))

# %%
data_df = pandify_header(samples)
data_df['Time'] = spec_df.Time.values

# %% [markdown]
# Push data frame to engines

# %%
puhsed_files = dview.push(dict(data_df = data_df ))

# %%
data_df.head()
# Out:
#          NIG                                               name  Monitor  \
# 5   0.000390  ./pilatus/InAs0799/InAs0799time3/InAs0799time3...    12360
# 6   0.000392  ./pilatus/InAs0799/InAs0799time3/InAs0799time3...    12707
# 11  0.000392  ./pilatus/InAs0799/InAs0799time3/InAs0799time3...    12273
# 12  0.000392  ./pilatus/InAs0799/InAs0799time3/InAs0799time3...    12741
# 13  0.000392  ./pilatus/InAs0799/InAs0799time3/InAs0799time3...    13010
#
#    Timestamp      Time
# 5        NaN  0.003226
# 6        NaN  0.999416
# 11       NaN  6.218830
# 12       NaN  7.126620
# 13       NaN  8.078640

# %%
obj = SPring8_image(data_df.name[-10])
obj.read_detector(2)
image = obj.img
range_pixel = [70,125, 280,370]
puhsed_files = dview.push(dict(range_pixel=range_pixel))
image = image[range_pixel[0]:range_pixel[1],range_pixel[2]:range_pixel[3]] 
e
fig,ax = subplots()
# image = image[0:70,0:100]
plt.imshow(log(image),cmap= cm.cubehelix)

# %% [markdown]
# ## 2D fit test

# %%
result = agf.gaussfitter.gaussfit(image)

# %%
fig,ax = subplots(figsize=(10,5))
params = result
(height, amplitude, x, y, width_x, width_y, rota) = params

imshow(log(image),cmap=cm.cubehelix)
contour((agf.gaussfitter.twodgaussian(params,shape=image.shape)),cmap=cm.Accent)
       

ax = gca()
text(2, 0.05, """
x : %.1f ,bkg: %.f ,
y : %.1f , peak: .%f ,
width_x : %.1f
width_y : %.1f
rot: %1.f """ %(x, y, height, amplitude, width_x, width_y, rota),
        fontsize=16, horizontalalignment='right',
        verticalalignment='bottom', transform=ax.transAxes)

colorbar()


names = ["height", "amplitude", "x", "y","width_x", "width_y", "rota"]

# %% [markdown]
# # monitor ? erorrs ?

# %%
start_time = tm.time()
samples = deque(dview.map_sync(lambda x: fit_parallel(x,data_df,range_pixel),files))
elapsed_time = tm.time() - start_time
print  "parallel fit done in {0} seconds, {1} miuntes".format(elapsed_time, elapsed_time/60)
# Out:
# parallel fit done in 163.391209841 seconds, 2.72318683068 miuntes

# %% [markdown]
# If needed dump them to disk..

# %%
pickle.dump(samples, open(str(name) +str(range_pixel)+'fit_Res' + ".p", "wb"))

# %%
print str(name) +str(range_pixel)+'fit_Res_zb' + ".p"
# Out:
# InAs0799time3[70, 125, 280, 370]fit_Res_zb.p

# %% [markdown]
# ## plot result  - WZ

# %%
WZ = pickle.load(open('rota[70, 125, 150, 300]fit_Res_zb.p',"rb")) 
fig,ax = subplots(len(samples[0]),1,figsize=(10,50))
for i,t in zip(samples,data_df.Time):
    for j,name in zip(range(len(samples[0])),names):
        ax[j].set_title(name)
        ax[j].plot(t,i[j],'k.')
fig.tight_layout()

# %%
zb = pickle.load(open('InAs0799time3fit_Res_zb.p',"rb"))
ax2 = [i.twinx() for i in ax]
for i,t in zip(zb,data_df.Time):
    for j, prop_name in zip(range(len(zb[0])),names):
        ax2[j].set_title(prop_name)
        ax2[j].plot(t,i[j],'y.')
fig.tight_layout()
fig.savefig('test.pdf')
fig

# %%
TW = pickle.load(open(a[1],"rb"))
ax3 = [i.twinx() for i in ax]
for i,t in zip(TW,data_df.Time):
    for j, prop_name in zip(range(len(zb[0])),names):
        ax3[j].set_title(prop_name)
        ax3[j].plot(t,i[j],'b.')
fig.tight_layout()
fig.savefig('test.pdf')
fig

# %%
fig,ax = subplots(figsize=(10,5))
index = -10
obj = SPring8_image(data_df.name[index])
ax.set_title( data_df.name[index].split('/')[-1])
obj.read_detector(2)
image = obj.img
range_pixel = [70,125, 150,300]
puhsed_files = dview.push(dict(range_pixel=range_pixel))

image = image[range_pixel[0]:range_pixel[1],range_pixel[2]:range_pixel[3]] 


params = samples[index]
(height, amplitude, x, y, width_x, width_y, rota) = params

imshow(log(image),cmap=cm.cubehelix)
contour((agf.gaussfitter.twodgaussian(params,shape=image.shape)),cmap=cm.Accent)
       

ax = gca()
text(2, 0.05, """
x : %.1f ,bkg: %.f ,
y : %.1f , peak: .%f ,
width_x : %.1f
width_y : %.1f
rot: %1.f """ %(x, y, height, amplitude, width_x, width_y, rota),
        fontsize=16, horizontalalignment='right',
        verticalalignment='bottom', transform=ax.transAxes)

colorbar()


names = ["height", "amplitude", "x", "y","width_x", "width_y", "rota"]

# %% [markdown]
# ## GIT

# %%
# !git add 'Napkin-2d-fitting.ipynb'
# !git commit  -m 'testing big WZ , dump saved on disk'

# %%
# !git add 'InAs0799time3[70, 125, 150, 300]fit_Res_zb.p'
# !git commit  -m 'commit fit result dump'
# Out:
# [parllelpimp 758c545] commit fit result dump
#  1 file changed, 7758 insertions(+)
#  create mode 100644 InAs0799time3[70, 125, 150, 300]fit_Res_zb.p
